# %% [markdown]
# # Machine Learning Workshp 1 : __An introduction to Machine Learning__
#
# __Welecome to our first workshop!__
# <br> It consists of five tasks of advancing difficulty.
# <br> Please devote approximately 15 minutes per task
# <br> Prior to each task we will discuss some theoretical aspects regarding fundamental machine learning concepts and we will explain the details of the Python functions and libraries that we will use.
#
# ## Table of Contents
# 1. [Data Visualization](#Data-Visualization)
#     1. [Scatterplot Definition](#Definition)
#     1. [A first example](#A-first-example)
#     1. [Add color to the markers](#Add-color-to-the-markers)
# 1. [Data Distributions](#Data-Distributions)
#     1. [Distribution Terminology](#Distribution-Terminology)
#     1. [Gaussian Distribution](#Gaussian-Distribution)
#     1. [Uniform Distribution](#Uniform-Distribution)
# 1. [Exercise 1: Create Classes](#Exercise-1:-Create-Classes)
#     1. [Useful hints for creating classes](#Useful-hints-for-creating-classes)
# 1. [Create a Line Plot](#Plot-Line)
# 1. [Exercise 2: Find the decision boundary](#Exercise-2:-Find-the-decision-boundary)
#     1. [Useful hints for finding the decision boundary](#useful-hints-for-finding-the-decision-boundary)
# 1. [Exercise 3: Classifying samples](#Exercise-3:-Classifying-samples)
#     1. [Useful hints for classifying samples](#useful-hints-for-classifying-samples)
# 1. [An introduction to regression analysis](#An-introduction-to-regression-analysis)
# 1. [Exercise 4: Reading a regression line](#Exercise-4:-Reading-a-regression-line)
#     1. [Regression line code](#regression-line-code)
#     1. [Provide answers as markdown documentation](#provide-answers-as-markdown-documentation)
# 1. [An introduction to multi-class classification](#An-introduction-to-multi-class-classification)
# 1. [Exercise 5: Multiclass classification problem](#Exercise-5:-Multiclass-classification-problem)
#     1. [Multiclass code](#multiclass-code)
#     2. [Useful hints for modifying the code](#useful-hints-for-modifying-the-code)
# 1. [References](#References)
# 1. [Workshop Evaluation](#Workshop-Evaluation)

# %% [markdown]
# __Let us start!!__

# %% [markdown]
# # Data Visualization
# <br> It is a very important task of each machine learning task.
# <br> Python has several modules that we can use for data visualization.
# <br> Among them the __[matplotlib](https://matplotlib.org/)__ is a very popular one. The ``` plt.scatter() ``` function is used to create scatterplots.

# %% [markdown]
# ## Definition
# <br> The scatterplot visualizes how two variables are related to each other.
# <br> Each data point is represented as a single dot or marker of our preferred shape.
# <br> We prefer the scatterplot visualization in cases where we wish to know the relationship between two variables.

# %% [markdown]
# ## A first example
# Suppose we have the weight in kilogramms for 6 people and their associated Body Mass Index (BMI) which is computed through the following formula : $BMI = Weight/ (Height) ^ 2$
# <br> We wish to create a scatterplot to __understand the relationship between body weight and bmi value__.
# <br> Firstly, we import the pyplot submodule from Matplotlib.
# <br> Then, we create one list containing the body weight in kilograms and another list containing the associated bmi value.
# <br> Afterwards, we create the scatterplot by using ```plt.scatter()``` with the two variables that we wish to compare as input arguments.
# <br> Finally, we need to explicitly display the figure by using the ```plt.show()``` function.
# <br> The ```plt.title(label,fontsize=NumericValue)``` is used to set a title for the entire plot.
# <br> A similar syntax is followed for ```plt.xlabel()``` and ```plt.ylabel()``` for setting the titles for x and y axes respectively.
# <br> The ```plt.grid(True,color='black',linestyle='-',linewidth=1)``` configures the grid lines.
# <br> The ```plt.xticks(TicksArray, LabelsArray, fontsize=NumericValue)``` is used to set the current tick locations and labels on the x-axis.
# <br> The syntax is similar for the ```plt.yticks()``` function.
# <br> The ```numpy.arange(start,stop,step)``` returns evenly spaced values within a given interval.
# <br> If we wish to use a __non-integer step__, such as the __0.1__, it is often better to use the ```numpy.linspace```function. It returns evenly spaced samples, calculated over the interval __StartValue...StopValue__.
# <br>The code is the following one:

# %%
import matplotlib.pyplot as plt

weight = [120, 50, 80, 65, 75, 92]
bmi = [34, 20, 28, 23, 26, 29]

plt.scatter(weight,bmi)
plt.title('BMI-Weight Association',fontsize=22)
plt.xlabel('Weight in kilograms',fontsize=16)
plt.ylabel('Body Mass Index',fontsize=16)
plt.xticks(np.arange(40, 121, 10), fontsize=12)
plt.yticks(np.arange(15, 36, 5), fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Add color to the markers
# <br> Let us plot the sample points with different colors according to their BMI values.
# <br> So, if $ BMI <= 25 $, we plot the points with blue color.
# <br> Else if $ 25 < BMI <= 30 $, we plot the points with magenta color.
# <br> Else we plot the points with red color.
# The code is the following:

# %%
import matplotlib.pyplot as plt

weight = [120, 50, 80, 65, 75, 92]
weight_1 = [50, 65]
bmi_1 = [20, 23]
weight_2 = [80, 75, 92]
bmi_2 = [26,28,29]
weight_3 = [120]
bmi_3 = [34]

plt.scatter(weight_1,bmi_1,c='blue')
plt.scatter(weight_2,bmi_2,c='magenta')
plt.scatter(weight_3,bmi_3,c='red')
plt.title('BMI-Weight Association',fontsize=22)
plt.xlabel('Weight in kilograms',fontsize=16)
plt.ylabel('Body Mass Index',fontsize=16)
plt.xticks(np.arange(40, 121, 10), fontsize=12)
plt.yticks(np.arange(15, 36, 5), fontsize=12)
plt.grid(True,color='black',linestyle='-',linewidth=0.5)
plt.show()

# %% [markdown]
# # Data Distributions
# 1. A distribution is simply a collection of data or scores for a variable.
# 1. Usually, these scores are arranged in order from smallest to largest observations and then can be presented graphically.

# %% [markdown]
# # Distribution Terminology
# 1. Each data distribution is described by the associated density function which quantifies the proportion of data change over the range of the distribution.
# 1. There are two types of density functions.
# 1. The __Probability density function (PDF)__ calculates the probability of observing a given value.
# 1. The __Cumulative Density Function (CDF)__ calculates the probability of an observation equal or less than a value.

# %% [markdown]
# ## Gaussian Distribution
# 1. It is also known as the __normal__ distribution.
# 1. This probability distribution is __symmetric__ about the mean value.
# 1. This imples that data __near the mean are more frequent__ in occurrence than data far from the mean.
# 1. It graphically appears as a "bell curve".
# 1. It can be described by just __two parameters__: The __mean value__ and the __standard deviation__.
# 1. For all normal distributions, __68.2% of the observations__ will appear within plus or minus __one standard deviation of the mean__.
# 1. __95.4% of the observations__ will fall within $+/-$ __two standard deviations of the mean__.
# 1. __99.7% of the observations__ will fall within $+/-$ __three standard deviations of the mean__.
# <br>
# <br>
# The following code segment is used to generate a normal distribution and plot its probability density function:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.stats import gaussian_kde

# Set a random seed for reproducibility
np.random.seed(42)

#Generate synthetic data from a normal distribution
mean_value =3.0
standard_deviation = 0.5
sample_size = 1000
synthetic_data = np.random.normal (mean_value, standard_deviation, sample_size)

# Plot the histogram of the synthetic data
plt.hist(synthetic_data, bins =30, density=True, alpha=0.5, label="Histogram")

# Fit a KDE to the data
kde = gaussian_kde(synthetic_data)
x_vals = np.linspace(min(synthetic_data),max(synthetic_data), 1000)
kde_vals = kde(x_vals)

# Plot the estimated PDF using KDE
plt.plot(x_vals, kde_vals, label="KDE", color='red')

# Plot the true PDF of the normal distribution for comparison
pdf_vals = norm.pdf(x_vals, mean_value, standard_deviation)
plt.plot(x_vals,pdf_vals, label="True PDF", linestyle='dashed', color='green')

# Set labels and legend
plt.xlabel("X")
plt.ylabel("Probability Density")
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Uniform Distribution
# 1. A uniform distribution is a probability distribution type in which all the values within a given range have the same possibility to occur.
# 1. The ```numpy.random.uniform(LowValue, HighValue, Size)``` draws samples from a uniform distribution.
# 1. It models situations where each outcome has an equal chance to happen.
# 1. So, there is no bias or preference for any particual value within the range.
# 1. The range of the distribution is defined by its lower bound (a) and its upper bound (b)
# 1. Its probability density function is given by: $f(x) =
# \begin{cases}
#     1 / b-a, & \text{if } a \leq x \leq b \\
#     0 , & \text{if }  x < a \\
#     0, & \text{if } x > b
# \end{cases}
# $
#
# The following code segment is used to generate a uniform distribution between 2 and 6, while also plotting its probability density function (PDF):

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of the uniform distribution
a = 2 # Lower bound
b = 6 # Upper bound

# Generate synthetic data from a uniform distribution
sample_size = 5000
uniform_data = np. random.uniform(a,b,sample_size)

# Plot the histogram of the synthetic data to visualize its distribution
plt.hist(uniform_data, bins = 30, density=True, alpha=0.5, label="Histogram")

#Plot the PDF of the uniform distribution
x_vals=np.linspace(a-1,b+1,sample_size) # Create a range of x values
pdf_vals = np.full_like(x_vals, 1/(b-a)) # PDF is constant within [a,b]
plt.plot(x_vals, pdf_vals, label='PDF',color='red')

# Set labels and legend
plt.xlabel("X")
plt.ylabel("Probability Density")
plt.legend()

#Show the plot
plt.show()

# %% [markdown]
# # Exercise 1: Create Classes
#
# For this task, you are required to **create and display** two different classes of data. Each class consists of $100$ uniformly distributed sample points (for this, you can use `numpy.random.uniform`, and you should fix the random seed for reproducibility):
# - The points of class 1 have $-2 < x < 2$ and $4 < y < 7$. Assign to the x coordinate a variable called `x1` and their y coordinate in a variable called `y1`.
# - The points of class 2 have $3 < x < 7$ and $0 < y < 4$. Assign the x coordinate a variable called `x2` and their y coordinate in a variable called `y2`.
#
# Plot each class **with a separate color**.
#
# **Remember** to label your axis, add a legend and a grid to your figure.
#
# The final result should look like this:
# ![Exercise%201.png](attachment:Exercise%201.png)

# %%
# Create Classes - place the code here
import matplotlib.pyplot as plt
import numpy as np

from dataclasses import dataclass

np.random.seed(42)

@dataclass(frozen=True)
class UniformDistribution2D:
    x_min: float
    x_max: float
    y_min: float
    y_max: float

    def generate_data_points(self, sample_size) -> (np.ndarray, np.ndarray):
        return (
            np.random.uniform(self.x_min, self.x_max, sample_size),
            np.random.uniform(self.y_min, self.y_max, sample_size)
        )

class1 = UniformDistribution2D(-2.0, 2.0, 4.0, 7.0)
class2 = UniformDistribution2D(3.0, 7.0, 0.0, 4.0)

sample_size = 100

(x1, y1) = class1.generate_data_points(sample_size)
(x2, y2) = class2.generate_data_points(sample_size)

plt.grid(True)
plt.scatter(x1, y1, c="blue", label="Cluster 1")
plt.scatter(x2, y2, c="red", label = "Cluster 2")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# # Plot Line
# 1. We will use the ```plt.plot()``` function.
# 1. This function takes two parameters, which are the x and y values.
#
# The following code segment is used to plot a line:

# %%
import matplotlib.pyplot as plt

# Define x and y data points for the line
x=[1,2,3,4,5]
y=[2,4,6,8,10]

# Create a line plot
plt.plot(x,y,c='red')

#Add labels and a title
plt.xlabel("X-axis", fontsize=12)
plt.ylabel("Y-axis", fontsize=12)
plt.title("Line Plot Example", fontsize=20)
plt.grid(True)
# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 2: Find the decision boundary
#
# **Find a correct decision boundary** that separates the classes created during the previous task. That decision boundary is defined with a function called `decision_boundary`. In this case, the decision boundary is a line. The general equation of a line is:
# $$
# y = ax + b
# $$
# Where the parameter $a$ is called `slope` and defines how steep the line is, and the parameter $b$ is called `intercept` and defines the point where the line intersects the y-axis (for $x=0$).
#
# **Change the values of** `slope` and `intercept` and **plot** the function defined by `decision_boundary` on the interval $x=[-7,7]$ in green.
#
# _Note:_ As you change the `slope` and `intercept` values, the provided code will plot your samples classified according to the decsion boundary you have defined.
#
# You should be using `np.linspace` and `np.plot` to solve this task.

# %%
import numpy as np
import matplotlib.pyplot as plt

from dataclasses import dataclass

np.random.seed(42)

# Stuff from previous task
@dataclass(frozen=True)
class UniformDistribution2D:
    x_min: float
    x_max: float
    y_min: float
    y_max: float

    def generate_data_points(self, sample_size) -> (np.ndarray, np.ndarray):
        return (
            np.random.uniform(self.x_min, self.x_max, sample_size),
            np.random.uniform(self.y_min, self.y_max, sample_size)
        )

class1 = UniformDistribution2D(-2.0, 2.0, 4.0, 7.0)
class2 = UniformDistribution2D(3.0, 7.0, 0.0, 4.0)

sample_size = 100

(x1, y1) = class1.generate_data_points(sample_size)
(x2, y2) = class2.generate_data_points(sample_size)

plt.grid(True)
plt.scatter(x1, y1, c="blue", label="Cluster 1")
plt.scatter(x2, y2, c="red", label = "Cluster 2")
plt.legend(loc="upper right")
########################

# CHANGE THE VALUES OF SLOPE AND INTERCEPT
def decision_boundary(x):
    slope = 4
    intercept = -6
    return slope*x + intercept


## FILL OUT TO PLOT THE DECISION BOUNDARY:
# Define a range of x-values for plotting
x_values = np.linspace(-7, 7, 100)
# Calculate the corresponding y-values based on the user-provided parameters
y_values = decision_boundary(x_values)
plt.plot(x_values, y_values, label='Decision Boundary', color='green')
plt.show()

# %% [markdown]
# Which is the optimal decision boundary?

# %% [markdown]
# ## Exercise 3: Classifying samples
#
# 1. You are given the following points: __(-4, -4), (-2, -4), (0, 0), (-6, 0), (-4, 2), (-2, 2).__
# 1. Could you identify in which classes these points correspond?
# 1. Please plot the points with the appropriate colour in the previously produced scatter plot.

# %% [markdown]
# ## Useful hints for classifying samples
# 1. Use the previously produced plot with the decision boundary line to identify the cluster that each point belongs.
# 1. Then, create separate lists for the x and y co-ordinates and display them in the same scatterplot.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Classifying samples - place the code here

# Stuff from previous task
def decision_boundary(x):
    slope = 4
    intercept = -6
    return slope*x + intercept

x_values = np.linspace(-7, 7, 100)
y_values = decision_boundary(x_values)

vals = np.array([[-4, -4], [-2, -4], [0, 0], [-6, 0], [-4, 2], [-2, 2]])
x_vals, y_vals = vals[...,0], vals[...,1]
########################

plt.scatter(x_vals, y_vals)
plt.plot(x_values, y_values, label='Decision Boundary', color='green')
plt.grid(True)
plt.show()

# %% [markdown]
# # An introduction to regression analysis
# 1. It is a common machine learning task to estimate the relationship between the __outcome__ of a given task __(dependnet variable)__ and one or more variables that we use as __features__ to __predict__ that outcome (__independnet variables)__.
# 1. The main difference between classification and regression is the __type of the output variable__.
# 1. We try to predict a __categorical or discrete output__ when dealing with a __classification__ problem.
# 1. In __regression__, the __output is numerical or continuous__.
# 1. The __linear regression__ is the most common model in regression analysis.
# 1. This model finds the relationship between the independent and dependent variables by __fitting a linear equation__.
# 1. The f(x) or y-value represents the independent variable, which we wish to predict.
# 1. The x-value, which is usually in the horizontal axis, shows the independent variable values.
# 1. We are making predictions by entering the independent variable's value (x-value) in the regression equation, and then computing the value of the idependent variable.

# %% [markdown]
# ## Exercise 4: Reading a regression line
#
# In the following two sections you are given the Python code to __1) create a regression line defined as a piecewise function__ and the __2) function display__.
#
# ### Description of a Piecewise Function
#
# Let's define a regression line through a piecewise function \(y\) that takes different forms in different intervals:
#
#
# $f(x) =
# \begin{cases}
#     x^3, & \text{if } x \leq 2 \\
#     2x + 4, & \text{if } 2 < x \leq 10 \\
#     0.2x^2 + 4, & \text{if } x > 10
# \end{cases}
# $
#
# - When \(x\) is less than or equal to 2, the function is defined as \(f(x) = x^3\).
# - When \(x\) is greater than 2 but less than or equal to 10, the function is defined as \(f(x) = 2x + 4\).
# - When \(x\) is greater than 10, the function is defined as \(f(x) = 0.2x + 4\).

# %% [markdown]
# ### Regression line code

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of the x values
x=np.linspace(0,20,400)

# Initialize an empty array for y values
y=np.empty_like(x)

# Calculate y values based on the piecewise function
for i, xi in enumerate(x):
    if xi<= 2:
        y[i]= pow(xi,3)
    elif xi> 2 and xi <=10:
        y[i] = 2*xi+4
    else:
        y[i] = 0.2*xi * xi +4

# Plot the function
plt.figure(figsize=(8,6))
plt.plot(x,y,label='Regression Line')
plt.xlim(0,20)
plt.ylim(0,84)
plt.xticks(np.arange(0, 20, 1), fontsize=12)
plt.yticks(np.arange(0, 84, 4), fontsize=12)
plt.xlabel('x-value', fontsize=22)
plt.ylabel('y-value',fontsize =22)
plt.legend(fontsize=24)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Provide answers as markdown documentation
# 1. Which is the function output for $x=0$ ?
# 1. Which is the function output for $x=8$ ?
# 1. Is it true that the increase in function output is greater from 1 to 2 rather than 5 to 6?
# 1. Change the code so as the function output would be equal to $y = 50$ for $x = 12$.
# 1. What is happening then at $ x=10$?

# %% [markdown]
# ### Answers
# 1)
# $$
# f(0) =
# \begin{cases}
#     x^3, & \text{if } 0 \leq 2 = \text{true} \\
#     2x + 4, & \text{if } 2 < 0 \leq 10 = \text{false} \\
#     0.2x^2 + 4, & \text{if } 0 > 10 = \text{false}
# \end{cases}
# $$
# so we choose the the $x^3$ case:
# $$
# (0)^3 = 0
# $$
#
# 2)
# $$
# f(8) =
# \begin{cases}
#     x^3, & \text{if } 8 \leq 2 = \text{false} \\
#     2x + 4, & \text{if } 2 < 8 \leq 10 = \text{true} \\
#     0.2x^2 + 4, & \text{if } 8 > 10 = \text{false}
# \end{cases}
# $$
# so we choose the $2x + 4$ option:
# $$
# 2(8) + 4 = 16 + 4 = 20
# $$
#
# 3)
# The function output between $1$ and $2$ is $x^3$ from the piecewise equation, while the function output between
# $5$ and $6$ is $2x + 4$. When $x = 1, y = (1)^3 = 1$ and when $x = 2, y = (2)^3 = 8$, so the difference of function output between $x = 1$ to $x = 2$ is $8 - 1 = 7$. When $x = 5, y = 2(5) + 4 = 14$ and when $x = 6, y = 2(6) + 4 = 16$, so the difference of function output between $x = 14$ to $x = 16$ is $16 -14 = 2$
#
# 4)
# Line between $(10, 24)$ and $(12, 50)$. $y = ax + b$ and $m = {\Delta y \over \Delta x}$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of the x values
x=np.linspace(0,20,400)

# Initialize an empty array for y values
y=np.empty_like(x)

# Calculate y values based on the piecewise function
for i, xi in enumerate(x):
    if xi<= 2:
        y[i]= pow(xi,3)
    elif xi> 2 and xi <=10:
        y[i] = 2*xi+4
    else:
        y[i] = 13 * xi - 106

# Plot the function
plt.figure(figsize=(8,6))
plt.plot(x,y,label='Regression Line')
plt.xlim(0,20)
plt.ylim(0,84)
plt.xticks(np.arange(0, 20, 1), fontsize=12)
plt.yticks(np.arange(0, 84, 4), fontsize=12)
plt.xlabel('x-value', fontsize=22)
plt.ylabel('y-value',fontsize =22)
plt.legend(fontsize=24)
plt.grid(True)
plt.show()

# %% [markdown]
# # An introduction to multi-class classification
# 1. We refer to a classification task with more than two classes.
# 1. It may be for example, a task in which we classify a set of images of fruits which could be oranges, apples or pears.
# 1. The multi-class classification makes the assumption that __each sample is assigned to one and only one label__.
# 1. A fruit can be either an apple or a pear but not both at the same time.

# %% [markdown]
# # Exercise 5: Multiclass classification problem
# 1. You are given the code for defining and visualizing three classes.
# 1. This is the so-called multi-class classification problem.
# 1. Please run the code and try to answer to the following questions:
#     1. In which class should the points (1,4), (5,7) and (3,2) be classified?
#     1. Update the given code to create a new class with points having y-value greater or equal to 6. Display this new class with a new color and also display the decision boundary.
#     1. What is happening then to the points with x-value greater than 4: $ x > 4 $?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate some sample data points
np.random.seed(0)
x = np.random.uniform(0, 8, 300)
y = np.random.uniform(0, 8, 300)

# Assign class labels based on the decision boundaries
class_labels = []
for i in range(len(x)):
    ############################
    ##### MODIFY THIS PART #####
    ############################
    if x[i] <= 4 and y[i] <= x[i]:
        class_labels.append(1)
    elif x[i] <= 4 and y[i] > x[i]:
        class_labels.append(2)
    else:
        class_labels.append(3)

class_labels = np.array(class_labels)

# Create scatter plots for each class with different colors
plt.figure(figsize=(8, 6))
plt.scatter(x[class_labels == 1], y[class_labels == 1], c='r', marker='o', label='Class 1')
plt.scatter(x[class_labels == 2], y[class_labels == 2], c='g', marker='s', label='Class 2')
plt.scatter(x[class_labels == 3], y[class_labels == 3], c='b', marker='^', label='Class 3')

# Plot decision boundaries
plt.plot([0, 4], [0, 4], 'k--', label='Decision Boundary: y=x')
plt.axvline(x=4, color='k', linestyle='--', label='Decision Boundary: x=4')

plt.xlabel('X')
plt.ylabel('Y')
#plt.legend()
plt.title('Separation of Three Classes based on Decision Boundaries')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Useful hints for modifying the code
# 1. Extend the __if - elif - else statement__ with one more condition checking for $ y>6$
# 2. Add a new plt.scatter function.
# 3. The produced image should look like the following output:
# ![Exercise%205.png](attachment:Exercise%205.png)

# %%
# Four-class classification - Place the code here
import numpy as np
import matplotlib.pyplot as plt

# Generate some sample data points
np.random.seed(0)
x = np.random.uniform(0, 8, 300)
y = np.random.uniform(0, 8, 300)

# Assign class labels based on the decision boundaries
class_labels = []
for i in range(len(x)):
    ############################
    ##### MODIFY THIS PART #####
    ############################

    # if x[i] <= 4 and y[i] <= x[i]:
    #     class_labels.append(1)
    # elif x[i] <= 4 and y[i] > x[i]:
    #     class_labels.append(2)
    # else:
    #     class_labels.append(3)

    if y[i] > 6:
        class_labels.append(3)
    elif x[i] > 4:
        class_labels.append(4)
    elif y[i] > x[i]:
        class_labels.append(2)
    else:
        class_labels.append(1)
    
class_labels = np.array(class_labels)

# Create scatter plots for each class with different colors
plt.figure(figsize=(8, 6))
plt.scatter(x[class_labels == 1], y[class_labels == 1], c='r', marker='o', label='Class 1')
plt.scatter(x[class_labels == 2], y[class_labels == 2], c='g', marker='s', label='Class 2')
plt.scatter(x[class_labels == 3], y[class_labels == 3], c='b', marker='^', label='Class 3')
plt.scatter(x[class_labels == 4], y[class_labels == 4], c='m', marker='*', label='Class 4')

# Plot decision boundaries
plt.plot([0, 4], [0, 4], 'k--', label='Decision Boundary: y=x')
plt.axvline(x=4, color='k', linestyle='--', label='Decision Boundary: x=4')
plt.axhline(y=6, color='k', linestyle='--', label='Decision Boundary: y=6')

plt.xlabel('X')
plt.ylabel('Y')
#plt.legend()
plt.title('Separation of Three Classes based on Decision Boundaries')
plt.grid(True)
plt.legend(loc="center right")
plt.show()

# %% [markdown]
# # References
# __[The matplotlib module](https://matplotlib.org/)__
# <br>
# __[Set axes titles](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.title.html)__
# <br>
# __[Configure grid lines](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.grid.html)__
# <br>
# __[Set the tick locations and labels on the x-axis](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xticks.html)__
# <br>
# __[Return evenly spaced values within a given interval](https://numpy.org/doc/stable/reference/generated/numpy.arange.html)__
# <br>
# __[Use of a non-integer step to return evenly spaced values within a given interval](https://numpy.org/doc/stable/reference/generated/numpy.linspace.html#numpy.linspace)__
# <br>
# __[Markdown for Jupyter notebooks](https://www.ibm.com/docs/en/watson-studio-local/1.2.3?topic=notebooks-markdown-jupyter-cheatsheet)__

# %% [markdown]
# # Workshop Evaluation
# <br> Please visit the following link for __[Workshop 1 evaluation](https://app.wooclap.com/PIHHOO?from=event-page)__
# <br> Tell us your opinion about this workshop and how we could become better in the next one.
# <br> __Your opinion matters!!!__
